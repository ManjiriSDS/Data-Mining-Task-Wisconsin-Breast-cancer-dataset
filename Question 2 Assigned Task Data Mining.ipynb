# %% [markdown]
# # Exploratory Data Analysis of Breast Cancer Wisconsins Diagnosis Data

# %% [markdown]
# #### Author: Manjiri Harishchandra Sawant

# %% [markdown]
# ### Importing necessary libraries

# %% [markdown]
# The following code written in python 3.x. Libraries provide pre-written functionally to perform necessary tasks

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
#read the data
b_cancer = pd.read_csv('C:/Users/Public/Documents/wdbc_cancerdata.csv', header = None)

# %%
#print number of rows and number of columns of data
b_cancer.shape
# Out:
# (569, 32)

# %%
#assigning column names to respective columns
b_cancer.columns = ['col1','col2','col3','col4','col5','col6','col7','col8','col9','col10',
                    'col11','col12','col13','col14','col15','col16','col17','col18','col19','col20',
                    'col21','col22','col23','col24','col25','col26','col27','col28','col29',
                    'col30','col31','col32']

# %%
# print first five rows of the data
b_cancer.head(5)
# Out:
#        col1 col2   col3   col4    col5    col6     col7     col8    col9  \
# 0    842302    M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001
# 1    842517    M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869
# 2  84300903    M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974
# 3  84348301    M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414
# 4  84358402    M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980
#
#      col10  ...  col23  col24   col25   col26   col27   col28   col29   col30  \
# 0  0.14710  ...  25.38  17.33  184.60  2019.0  0.1622  0.6656  0.7119  0.2654
# 1  0.07017  ...  24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860
# 2  0.12790  ...  23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 3  0.10520  ...  14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 4  0.10430  ...  22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
#
#     col31    col32
# 0  0.4601  0.11890
# ...

# %%
#Checking missing values
b_cancer.isnull().sum()
# Out:
# col1     0
# col2     0
# col3     0
# col4     0
# col5     0
# col6     0
# col7     0
# col8     0
# col9     0
# col10    0
# col11    0
# col12    0
# col13    0
# col14    0
# col15    0
# col16    0
# col17    0
# col18    0
# col19    0
# col20    0
# col21    0
# col22    0
# col23    0
# col24    0
# col25    0
# col26    0
# col27    0
# col28    0
# col29    0
# col30    0
# col31    0
# col32    0
# dtype: int64

# %%
#Check the data type of all columns:
print(b_cancer.dtypes)
# Out:
# col1       int64
# col2      object
# col3     float64
# col4     float64
# col5     float64
# col6     float64
# col7     float64
# col8     float64
# col9     float64
# col10    float64
# col11    float64
# col12    float64
# col13    float64
# col14    float64
# col15    float64
# col16    float64
# col17    float64
# col18    float64
# col19    float64
# col20    float64
# col21    float64
# col22    float64
# col23    float64
# col24    float64
# col25    float64
# col26    float64
# col27    float64
# col28    float64
# col29    float64
# col30    float64
# col31    float64
# col32    float64
# dtype: object

# %%
#Identifying Categorical features
categorical_data = b_cancer.select_dtypes(exclude = np.number)
categorical_col = categorical_data.columns
print('Categorical Features:')
print(categorical_data.head(5))
# Out:
# Categorical Features:
#   col2
# 0    M
# 1    M
# 2    M
# 3    M
# 4    M

# %%
#Creating frequency table for categorical variable
cases = b_cancer['col2'].value_counts()
print('Total No of Benign Cases B :', 'Total No of Malignant Cases M :')
print(cases)
# Out:
# Total No of Benign Cases B : Total No of Malignant Cases M :
# B    357
# M    212
# Name: col2, dtype: int64

# %%
#finding percentage of each class in the categorical features col2
class_value = (b_cancer['col2'].value_counts()/b_cancer['col2'].value_counts().sum())*100
print(class_value)
# Out:
# B    62.741652
# M    37.258348
# Name: col2, dtype: float64

# %%
b_cancer['col2'].value_counts().plot.bar()

# %%
#Removing Unnecessary column
b_cancer.drop(['col1'], axis = 1, inplace=True)

# %% [markdown]
# ### For each attributes find its Mean for each Class of 'col2' ie Diagnosis in whole sample

# %%
b_cancer.groupby('col2').mean()
# Out:
#            col3       col4        col5        col6      col7      col8  \
# col2
# B     12.146524  17.914762   78.075406  462.790196  0.092478  0.080085
# M     17.462830  21.604906  115.365377  978.376415  0.102898  0.145188
#
#           col9     col10     col11     col12  ...      col23      col24  \
# col2                                          ...
# B     0.046058  0.025717  0.174186  0.062867  ...  13.379801  23.515070
# M     0.160775  0.087990  0.192909  0.062680  ...  21.134811  29.318208
#
#            col25        col26     col27     col28     col29     col30  \
# col2
# B      87.005938   558.899440  0.124959  0.182673  0.166238  0.074444
# M     141.370330  1422.286321  0.144845  0.374824  0.450606  0.182237
#
#          col31     col32
# col2
# B     0.270246  0.079442
# M     0.323468  0.091530
#
# [2 rows x 30 columns]

# %% [markdown]
# ### For each attributes find its Variance for each Class of 'col2' ie Diagnosis in whole sample

# %%
b_cancer.groupby('col2').var(ddof = 0)
# Out:
#            col3       col4        col5           col6      col7      col8  \
# col2
# B      3.161342  15.916312  139.025062   17982.517411  0.000180  0.001136
# M     10.217009  14.217014  475.372918  134739.778217  0.000158  0.002901
#
#           col9     col10     col11     col12  ...      col23      col24  \
# col2                                          ...
# B     0.001882  0.000252  0.000614  0.000045  ...   3.914821  30.098989
# M     0.005601  0.001176  0.000760  0.000057  ...  18.262416  29.397769
#
#            col25          col26     col27     col28     col29     col30  \
# col2
# B     182.469633   26690.452717  0.000399  0.008473  0.019648  0.001278
# M     863.625089  355878.792502  0.000476  0.028890  0.032789  0.002134
#
#          col31     col32
# col2
# B     0.001738  0.000190
# M     0.005552  0.000462
#
# [2 rows x 30 columns]

# %% [markdown]
# ### For each attributes find its Standard Deviation for each Class of 'col2' ie Diagnosis in whole sample

# %%
b_cancer.groupby('col2').std(ddof = 0)
# Out:
#           col3      col4       col5        col6      col7      col8      col9  \
# col2
# B     1.778016  3.989525  11.790889  134.098909  0.013427  0.033703  0.043381
# M     3.196406  3.770546  21.803048  367.069174  0.012578  0.053860  0.074842
#
#          col10     col11     col12  ...     col23     col24      col25  \
# col2                                ...
# B     0.015886  0.024772  0.006738  ...  1.978591  5.486255  13.508132
# M     0.034293  0.027573  0.007555  ...  4.273455  5.421971  29.387499
#
#            col26     col27     col28     col29     col30     col31     col32
# col2
# B     163.372130  0.019985  0.092051  0.140171  0.035747  0.041686  0.013785
# M     596.555775  0.021818  0.169970  0.181078  0.046198  0.074509  0.021502
#
# [2 rows x 30 columns]
